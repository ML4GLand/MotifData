# %%
from pkg_resources import resource_filename

# %%
import numpy as np
import motifdata as md

# %%
def describe_motif_set(motif_set):
    print(f"# motifs: {len(motif_set)}")
    print(f"Alphabet: {motif_set.alphabet}")
    print(f"Version: {motif_set.version}")
    print(f"Strands: {motif_set.strands}")
    print(f"Background: {motif_set.background}")
    print(f"Background source: {motif_set.background_source}")

# %%
def print_all_motifs(motif_set):
    for motif in motif_set:
        print(f"Identifer: {motif.identifier}")
        print(f"Name: {motif.name}")
        print(f"Consensus: {motif.consensus}")
        print(f"PFM: {motif.pfm} with shape {motif.pfm.shape}")
        print()

# %% [markdown]
# # Convert MotifSets to BioPython and kernel

# %%
meme_file = resource_filename("motifdata", "resources/sample.meme")

# %%
motif_set = md.read_meme(meme_file)

# %%
motif_set
# Out:
# MotifSet with 6 motifs

# %%
md.to_biopython(motif_set)
# Out:
# [<Bio.motifs.jaspar.Motif at 0x15552a838490>,
#  <Bio.motifs.jaspar.Motif at 0x15552bc95670>,
#  <Bio.motifs.jaspar.Motif at 0x15552a838520>,
#  <Bio.motifs.jaspar.Motif at 0x15552a838310>,
#  <Bio.motifs.jaspar.Motif at 0x15552a838220>,
#  <Bio.motifs.jaspar.Motif at 0x15552bf2a3d0>]

# %%
md.to_kernel(motif_set, size=(256, 4, 13))
# Out:
# tensor([[[ 5.1000e-01,  6.3000e-01,  9.9600e-01,  ...,  1.3640e+00,
#            2.7820e+00,  5.0200e-01],
#          [ 1.5060e+00,  1.5940e+00,  1.2120e+00,  ...,  1.1200e-01,
#            3.2600e-01,  1.7280e+00],
#          [ 4.7800e-01,  7.9600e-01,  7.8800e-01,  ...,  1.4400e-01,
#            4.7800e-01,  1.2660e+00],
#          [ 1.5060e+00,  9.8200e-01,  1.0040e+00,  ...,  2.3820e+00,
#            4.1400e-01,  5.0200e-01]],
#
#         [[ 5.2400e-01,  6.7200e-01,  1.6400e+00,  ..., -3.6482e-02,
#           -1.0093e-02,  4.1355e-02],
#          [ 1.8680e+00,  1.3840e+00,  9.2000e-01,  ...,  2.4633e-02,
#            2.8663e-02, -1.9624e-02],
#          [ 5.6000e-01,  3.7200e-01,  3.0000e-01,  ...,  6.5665e-03,
#            2.7774e-02, -3.8307e-02],
#          [ 1.0480e+00,  1.5720e+00,  1.1400e+00,  ..., -3.1951e-02,
#            2.7186e-02,  3.9633e-02]],
#
#         [[ 2.1818e+00,  5.4546e-01,  1.8182e-01,  ...,  1.7756e-02,
#           -3.1422e-02, -3.3219e-02],
#          [ 1.2727e+00,  1.4545e+00,  2.5455e+00,  ...,  2.3210e-02,
#           -3.4600e-02, -5.3452e-03],
#          [ 3.6364e-01,  2.0000e+00,  1.2727e+00,  ...,  4.8462e-03,
#           -1.0738e-02,  3.7096e-02],
#          [ 1.8182e-01,  0.0000e+00,  0.0000e+00,  ...,  1.4271e-02,
#            1.4064e-02, -2.9110e-02]],
#
#         ...,
#
#         [[-9.9045e-03, -2.3074e-02, -3.5122e-02,  ...,  3.5789e-02,
#            1.0746e-02,  1.1412e-02],
#          [-3.9768e-02,  1.3818e-02, -1.2751e-02,  ..., -3.2531e-02,
#           -3.4042e-02, -3.4258e-02],
#          [ 2.5360e-02, -1.8908e-03,  2.2626e-02,  ..., -2.7728e-02,
#            2.4811e-02, -3.1481e-03],
#          [ 2.3398e-02,  3.7064e-02, -3.7929e-02,  ...,  1.4808e-02,
#            2.0891e-03,  2.2370e-03]],
#
#         [[ 1.4010e-02,  2.1810e-03, -1.0163e-02,  ...,  1.9970e-02,
#            3.4408e-03,  2.5848e-02],
#          [ 1.8605e-02, -5.1127e-03, -2.5827e-02,  ...,  2.2526e-02,
#            2.3807e-02, -2.3699e-02],
#          [-3.3077e-02,  3.5383e-02, -1.1048e-02,  ..., -2.6976e-02,
#            1.4234e-02, -2.2779e-02],
#          [ 3.2895e-03, -3.0371e-03, -1.0516e-02,  ..., -3.7694e-02,
#           -8.6312e-03, -2.4183e-02]],
#
#         [[-1.7816e-02,  3.5374e-02, -1.7745e-02,  ..., -3.3371e-02,
#            3.2039e-02,  1.9285e-02],
#          [ 2.6470e-03, -1.1490e-02, -1.3547e-02,  ..., -2.7967e-02,
#           -7.8568e-03,  1.5589e-02],
#          [-1.6667e-02, -8.4648e-03,  4.1278e-03,  ...,  2.9574e-02,
#            3.6655e-02,  8.7343e-03],
#          [-1.0257e-02, -1.7864e-02, -4.1930e-02,  ...,  5.4644e-03,
#            3.3298e-02,  3.7690e-02]]])

# %% [markdown]
# # Turn a kernel into a MotifSet

# %%
# Create a dummy random position frequency matrix (pfm) where every column sums to 1
pfms = np.random.rand(10, 4, 13)
pfms = pfms / pfms.sum(axis=1, keepdims=True)

# %%
motif_set = md.from_kernel(
    pfms
)
describe_motif_set(motif_set)
# Out:
# # motifs: 10
# Alphabet: ACGT
# Version: 5
# Strands: + -
# Background: None
# Background source: None

# %%
print_all_motifs(motif_set)
# Out:
# Identifer: filter_0
# Name: filter_0
# Consensus: TATTGTGGGGCCT
# PFM: [[0.22610029 0.27962686 0.21137976 0.28289309]
#  [0.40195002 0.30503644 0.108327   0.18468653]
#  [0.40408357 0.05074357 0.06754875 0.47762411]
#  [0.23895361 0.29700062 0.10161464 0.36243113]
#  [0.21949819 0.27022422 0.28440474 0.22587285]
#  [0.34930191 0.16656206 0.12790778 0.35622825]
#  [0.31203591 0.19334074 0.33238604 0.1622373 ]
#  [0.38090744 0.01062224 0.47884038 0.12962994]
#  [0.20905434 0.2090581  0.44762271 0.13426486]
#  [0.32923509 0.25417944 0.345152   0.07143346]
#  [0.21707847 0.40479263 0.04253592 0.33559298]
#  [0.15210358 0.36653929 0.25732524 0.22403189]
#  [0.12806442 0.29583317 0.26924801 0.3068544 ]] with shape (13, 4)
#
# Identifer: filter_1
# Name: filter_1
# Consensus: GCAGGTCACGGAA
# PFM: [[0.08021398 0.1915247  0.42100144 0.30725988]
#  [0.14771469 0.35009898 0.29466972 0.20751661]
#  [0.31765414 0.28341791 0.21929399 0.17963396]
#  [0.1834894  0.0572398  0.51603988 0.24323092]
#  [0.27828029 0.28374887 0.37807133 0.05989951]
#  [0.27320817 0.1600426  0.01853563 0.5482136 ]
#  [0.15179294 0.40137213 0.35309187 0.09374307]
#  [0.29297242 0.2738587  0.18249588 0.25067301]
#  [0.31468888 0.57974839 0.08152    0.02404273]
#  [0.17777428 0.06405258 0.49376913 0.26440401]
#  [0.01243782 0.22026335 0.6681239  0.09917493]
#  [0.66730425 0.05728151 0.20545495 0.0699593 ]
#  [0.43515896 0.16521152 0.07731305 0.32231647]] with shape (13, 4)
#
# Identifer: filter_2
# Name: filter_2
# Consensus: GTAATTTATTCCG
# PFM: [[0.13411596 0.31745665 0.3664891  0.18193829]
#  [0.24266961 0.16901979 0.22698682 0.36132379]
#  [0.47843798 0.13006038 0.23293336 0.15856828]
# Name: filter_6
# Consensus: TCTATGCGAACCG
# PFM: [[0.21021838 0.2889104  0.03039662 0.4704746 ]
#  [0.24103728 0.37316964 0.07453391 0.31125917]
#  [0.13074714 0.06498139 0.38992779 0.41434368]
#  [0.35794491 0.30137701 0.00149695 0.33918114]
#  [0.37657165 0.02442404 0.21605068 0.38295363]
#  [0.03588391 0.39499927 0.39509758 0.17401924]
#  [0.30338317 0.31033301 0.26462063 0.12166319]
#  [0.26481566 0.19948889 0.27608232 0.25961314]
#  [0.71565633 0.12643957 0.05664456 0.10125954]
#  [0.29023879 0.27875203 0.28282068 0.1481885 ]
#  [0.2802192  0.4837742  0.17548926 0.06051734]
#  [0.2678694  0.41851585 0.1684684  0.14514634]
#  [0.01272637 0.345013   0.41071117 0.23154945]] with shape (13, 4)
#
# Identifer: filter_7
# Name: filter_7
# Consensus: CGCTCTAGAGTAG
# PFM: [[0.20666919 0.35646274 0.2077489  0.22911917]
#  [0.10442702 0.15302846 0.65453801 0.08800651]
#  [0.18669673 0.53143807 0.14509352 0.13677168]
#  [0.20646288 0.27913033 0.19862042 0.31578637]
#  [0.23890515 0.30916421 0.23071292 0.22121772]
#  [0.23954326 0.20694341 0.27519451 0.27831882]
#  [0.36190507 0.19258859 0.14887258 0.29663376]
#  [0.10300911 0.19425444 0.45154195 0.25119449]
#  [0.74308244 0.10971778 0.09609066 0.05110913]
#  [0.31668064 0.00737884 0.54068151 0.13525902]
#  [0.20207961 0.2975309  0.19170001 0.30868948]
#  [0.58233784 0.00176306 0.35016654 0.06573255]
#  [0.33620435 0.06201142 0.4114503  0.19033392]] with shape (13, 4)
#
# Identifer: filter_8
# Name: filter_8
# Consensus: TATATTAGGGATC
# PFM: [[0.30814296 0.17499167 0.08485967 0.43200569]
#  [0.38562765 0.25199541 0.32755715 0.03481979]
#  [0.19345873 0.31360092 0.11007131 0.38286904]
#  [0.46094557 0.28833334 0.09681816 0.15390293]
#  [0.15032942 0.23226715 0.24878438 0.36861904]
#  [0.34684671 0.15861468 0.04838966 0.44614896]
#  [0.74930229 0.02695233 0.06574168 0.1580037 ]
#  [0.27827174 0.10980993 0.34444716 0.26747117]
#  [0.01814711 0.22006947 0.5198728  0.24191062]
#  [0.19229692 0.2983037  0.35519817 0.15420122]
#  [0.43000098 0.0011954  0.20817735 0.36062626]
#  [0.04461406 0.2927602  0.31886477 0.34376097]
#  [0.19512514 0.32965357 0.18552609 0.2896952 ]] with shape (13, 4)
#
# Identifer: filter_9
# Name: filter_9
# Consensus: GCCTTTATGCGCC
# PFM: [[0.27332533 0.19393018 0.29034744 0.24239705]
#  [0.26037013 0.35179611 0.333597   0.05423675]
#  [0.12157837 0.3222559  0.26732772 0.288838  ]
#  [0.25736044 0.33119993 0.03548479 0.37595483]
#  [0.30582559 0.00340224 0.33483489 0.35593728]
#  [0.24592333 0.07630063 0.29846425 0.3793118 ]
#  [0.47862504 0.37615432 0.12525086 0.01996978]
#  [0.32908847 0.14766195 0.18784119 0.33540839]
#  [0.00170768 0.41311772 0.42712537 0.15804923]
#  [0.32447154 0.33490288 0.02250514 0.31812045]
#  [0.26549048 0.25394348 0.29226768 0.18829836]
#  [0.08243824 0.44635399 0.37523147 0.0959763 ]
#  [0.08929559 0.39558959 0.3826914  0.13242342]] with shape (13, 4)

# %% [markdown]
# # DONE!

# %% [markdown]
# ---

# %% [markdown]
# # Scratch
